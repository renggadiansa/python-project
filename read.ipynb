# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#from sklearn import liner_model

# %%
df = pd.read_csv('trade.csv')
df
# Out:
#        Direction  Year        Date    Weekday Country Commodity  \
# 0        Exports  2015  01/01/2015   Thursday     All       All
# 1        Exports  2015  02/01/2015     Friday     All       All
# 2        Exports  2015  03/01/2015   Saturday     All       All
# 3        Exports  2015  04/01/2015     Sunday     All       All
# 4        Exports  2015  05/01/2015     Monday     All       All
# ...          ...   ...         ...        ...     ...       ...
# 98502  Reimports  2021  20/02/2021   Saturday     All       All
# 98503  Reimports  2021  21/02/2021     Sunday     All       All
# 98504  Reimports  2021  22/02/2021     Monday     All       All
# 98505  Reimports  2021  23/02/2021    Tuesday     All       All
# 98506  Reimports  2021  24/02/2021  Wednesday     All       All
#
#       Transport_Mode Measure      Value  Cumulative
# 0                All       $  104000000   104000000
# 1                All       $   96000000   200000000
# ...

# %%
# %matplotlib inline
plt.scatter(df.Year,df.Date)
